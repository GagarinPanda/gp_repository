# %% [markdown]
# # Рынок вакансий дата- и BI-аналитиков в Европе (по данным Linkedln)

# %% [markdown]
# ## Описание проекта ##

# %% [markdown]
# ### Цель ###

# %% [markdown]
# Подготовка дашборда с визуалицацией информации о рынке вакансий дата- и BI-аналитиков в Европе.

# %% [markdown]
# ### Источник данных ###

# %% [markdown]
# Информация о вакансиях за неделю в виде csv-файла, полученного парсингом с Linkedln 07.09.2022г.

# %% [markdown]
# ### Ход выполнения ###

# %% [markdown]
# 1. Получение из представленного csv-файла необходимых атрибутов:
#     - наименование вакансии;
#     - город;
#     - страна;
#     - тип занятости;
#     - название компании;
#     - количество работников в компании;
#     - сфера деятельности компании;
#     - требуемые hard-skills;
#     - дата публикации вакансии;
#     - количество кандидатов на вакансию.
# 2. Предобработка данных:
#     - фильтрация датафрейма по релевантным вакансиям и атрибутам;
#     - обработка пропусков и дубликатов.
# 3. Визуализация данных:
#     - построение дашборда в Tableau.
#     - содержание дашборда:
#         - фильтры: по стране, по типу занятости;
#         - количество вакансий (абсолютные значения) – индикатор;
#         - количество вакансий по странам (относительные величины) — stack bar chart;
#         - количество вакансий по городам - map;
#         - тип занятости — pie chart;
#         - список нанимающих компаний с указанием количества вакансий, отсортированный в порядке убывания — heat map;
#         - ТОП-10 сфер деятельности компаний — barchart;
#         - размер компаний и количество вакансий — pie chart;
#         - требуемые hard-skills — barchart;
#         - зависимость количества кандидатов на вакансию от даты публикации объявления — линейный график.

# %% [markdown]
# ## Получение из csv-файла необходимых атрибутов ##

# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import seaborn as sns
import re
from datetime import datetime
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
df = pd.read_csv('D:\Агарев\Yandex_Practicum\Мастерская\masterskaya_yandex_2022_09_07.csv')

# %% [markdown]
# ### Наименование вакансии

# %%
df['title'] = df['html'].apply(lambda x:  BeautifulSoup(x).find('h2').text.strip())

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst

# %% [markdown]
# ### Город

# %%
def get_geo(cell):
    try:
        return BeautifulSoup(cell).find('span', class_ = 'jobs-unified-top-card__bullet').text.strip()
    except:
        return np.nan

# %%
df['geo'] = df['html'].apply(get_geo)

# %%
def get_city(cell):
    if len(cell.split(',')) > 1:
        return cell.split(',')[0].strip()
    elif "Metropolitan" in cell or "Greater" in cell:
        return cell.replace('Greater', '').replace('Metropolitan', '').replace('Area', '').replace('Region','').strip()
    else:
        return np.nan

# %%
df['city'] = df['geo'].apply(get_city)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania

# %% [markdown]
# ### Страна

# %%
def get_country(cell):
    if len(cell.split(',')) > 1:
        return cell.split(',')[-1].strip()
    elif "Metropolitan" in cell or "Greater" in cell or "Region" in cell:
        return np.nan
    else:
        return cell

# %%
df['country'] = df['geo'].apply(get_country)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  country
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges   France
# 1             Toulouse, Occitanie, France                    Toulouse   France
# 2   Skara, Vastra Gotaland County, Sweden                       Skara   Sweden
# 3  West Flanders, Flemish Region, Belgium               West Flanders  Belgium
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania  Germany

# %% [markdown]
# ### Тип занятости

# %%
def get_workplace_type(cell):
    try:
        return BeautifulSoup(cell).find('span', class_ = 'jobs-unified-top-card__workplace-type').text.strip()
    except:
        return np.nan

# %%
df['workplace_type'] = df['html'].apply(get_workplace_type)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type
# 0   France        On-site
# 1   France        On-site
# 2   Sweden         Remote
# 3  Belgium         Remote
# 4  Germany         Remote

# %% [markdown]
# ### Название компании

# %%
def company_name(cell):
    try:
        return BeautifulSoup(cell).find('span', class_ = 'jobs-unified-top-card__company-name').text.strip()
    except:
        return np.nan

# %%
df['company_name'] = df['html'].apply(company_name)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions

# %% [markdown]
# ### Количество работников в компании

# %%
def employees(cell):
    try:
        return BeautifulSoup(cell).find('div', class_ = 'mt5 mb2').find_all(
            'li', class_ = 'jobs-unified-top-card__job-insight')[1].text.strip().split('·', 1)[0]
    except:
        return np.nan

# %%
df['employees'] = df['html'].apply(employees)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name  \
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions
#
#                  employees
# 0       10,001+ employees
# 1  5,001-10,000 employees
# 2       10,001+ employees
# 3       10,001+ employees
# 4       10,001+ employees

# %% [markdown]
# ### Сфера деятельности компании

# %%
def company_specialization(cell):
    try:
        return BeautifulSoup(cell).find('div', class_ = 'mt5 mb2').find_all(
            'li', class_ = 'jobs-unified-top-card__job-insight')[1].text.strip().split('·', 1)[1]
    except:
        return np.nan

# %%
df['company_specialization'] = df['html'].apply(company_specialization)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name  \
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions
#
#                  employees            company_specialization
# 0       10,001+ employees    Retail Luxury Goods and Jewelry
# 1  5,001-10,000 employees      IT Services and IT Consulting
# 2       10,001+ employees      IT Services and IT Consulting
# 3       10,001+ employees      IT Services and IT Consulting
# 4       10,001+ employees      IT Services and IT Consulting

# %% [markdown]
# ### Требуемые hard-skills

# %%
df['description'] = df['html'].apply(lambda x: BeautifulSoup(x).find('div', {'id':'job-details'}).text.strip())

# %%
skills = (['datahub', 'api', 'github', 'google analytics', 'adobe analytics', 'ibm coremetrics', 'omniture'
            'gitlab', 'erwin', 'hadoop', 'spark', 'hive'
           'databricks', 'aws', 'gcp', 'azure','excel',
            'redshift', 'bigquery', 'snowflake',  'hana'
            'grafana', 'kantar', 'spss', 
           'asana', 'basecamp', 'jira', 'dbeaver','trello', 'miro', 'salesforce', 
           'rapidminer', 'thoughtspot',  'power point',  'docker', 'jenkins','integrate.io', 'talend', 'apache nifi','aws glue','pentaho','google data flow',
             'azure data factory','xplenty','skyvia','iri voracity','xtract.io','dataddo', 'ssis',
             'hevo data','informatica','oracle data integrator','k2view','cdata sync','querysurge', 
             'rivery', 'dbconvert', 'alooma', 'stitch', 'fivetran', 'matillion','streamsets','blendo',
             'iri voracity','logstash', 'etleap', 'singer', 'apache camel','actian', 'airflow', 'luidgi', 'datastage',
           'python', 'vba', 'scala', ' r ', 'java script', 'julia', 'sql', 'matlab', 'java', 'html', 'c++', 'sas',
           'data studio', 'tableau', 'looker', 'powerbi', 'cognos', 'microstrategy', 'spotfire',
             'sap business objects','microsoft sql server', 'oracle business intelligence', 'yellowfin',
             'webfocus','sas visual analytics', 'targit', 'izenda',  'sisense', 'statsbot', 'panorama', 'inetsoft',
             'birst', 'domo', 'metabase', 'redash', 'power bi', 'alteryx', 'dataiku', 'qlik sense', 'qlikview'
          ])

# %%
def get_skills(cell):
    list_skills = []
    for skill in skills:
        if skill in cell.lower().replace('powerbi', 'power bi'):
            list_skills.append(skill)
    return list_skills

# %%
df['skills'] = df.description.apply(get_skills)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name  \
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions
#
#                  employees            company_specialization  \
# 0       10,001+ employees    Retail Luxury Goods and Jewelry
# 1  5,001-10,000 employees      IT Services and IT Consulting
# 2       10,001+ employees      IT Services and IT Consulting
# 3       10,001+ employees      IT Services and IT Consulting
# 4       10,001+ employees      IT Services and IT Consulting
#
#                                          description        skills
# 0  LA SOCIETE : \nCréée en 1926, la société Beyra...  [api, excel]
# 1  Dans le cadre de la croissance de nos activité...      [matlab]
# 2  TELUS International AI-Data Solutions partners...            []
# 3  TELUS International AI-Data Solutions partners...            []
# 4  TELUS International AI-Data Solutions partners...            []

# %% [markdown]
# ### Дата публикации вакансии

# %%
def publication_date(cell):
    try:
        return BeautifulSoup(cell).find('span', class_ = 'jobs-unified-top-card__posted-date').text.strip()
    except:
        return np.nan

# %%
df['publication_date'] = df['html'].apply(publication_date)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name  \
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions
#
#                  employees            company_specialization  \
# 0       10,001+ employees    Retail Luxury Goods and Jewelry
# 1  5,001-10,000 employees      IT Services and IT Consulting
# 2       10,001+ employees      IT Services and IT Consulting
# 3       10,001+ employees      IT Services and IT Consulting
# 4       10,001+ employees      IT Services and IT Consulting
#
#                                          description        skills  \
# 0  LA SOCIETE : \nCréée en 1926, la société Beyra...  [api, excel]
# 1  Dans le cadre de la croissance de nos activité...      [matlab]
# 2  TELUS International AI-Data Solutions partners...            []
# 3  TELUS International AI-Data Solutions partners...            []
# 4  TELUS International AI-Data Solutions partners...            []
#
#   publication_date
# 0   13 minutes ago
# 1       4 days ago
# 2       6 days ago
# 3       6 days ago
# 4      8 hours ago

# %% [markdown]
# ### Количество кандидатов на вакансию

# %%
def applicants(cell):
    try:
        return BeautifulSoup(cell).find('span', class_ = 'jobs-unified-top-card__applicant-count').text.strip().split(' ', 1)[0]
    except:
        return np.nan

# %%
df['applicants'] = df['html'].apply(applicants)

# %%
df.head()
# Out:
#    Unnamed: 0                                               html  \
# 0           0  \n  <div>\n    <div class="\n        jobs-deta...
# 1           1  \n  <div>\n    <div class="\n        jobs-deta...
# 2           2  \n  <div>\n    <div class="\n        jobs-deta...
# 3           3  \n  <div>\n    <div class="\n        jobs-deta...
# 4           4  \n  <div>\n    <div class="\n        jobs-deta...
#
#                                                title  \
# 0  Stage - Assistant Ingénieur Qualité - Beyrand ...
# 1  développeur matlab/simulink, secteur automobil...
# 2                                Online Data Analyst
# 3                      Online Data Analyst - Belgium
# 4                                       Data Analyst
#
#                                       geo                        city  \
# 0     Limoges, Nouvelle-Aquitaine, France                     Limoges
# 1             Toulouse, Occitanie, France                    Toulouse
# 2   Skara, Vastra Gotaland County, Sweden                       Skara
# 3  West Flanders, Flemish Region, Belgium               West Flanders
# 4     Mecklenburg-West Pomerania, Germany  Mecklenburg-West Pomerania
#
#    country workplace_type                           company_name  \
# 0   France        On-site                                 Hermès
# 1   France        On-site                                   AUSY
# 2   Sweden         Remote  TELUS International AI Data Solutions
# 3  Belgium         Remote                    TELUS International
# 4  Germany         Remote  TELUS International AI Data Solutions
#
#                  employees            company_specialization  \
# 0       10,001+ employees    Retail Luxury Goods and Jewelry
# 1  5,001-10,000 employees      IT Services and IT Consulting
# 2       10,001+ employees      IT Services and IT Consulting
# 3       10,001+ employees      IT Services and IT Consulting
# 4       10,001+ employees      IT Services and IT Consulting
#
#                                          description        skills  \
# 0  LA SOCIETE : \nCréée en 1926, la société Beyra...  [api, excel]
# 1  Dans le cadre de la croissance de nos activité...      [matlab]
# 2  TELUS International AI-Data Solutions partners...            []
# 3  TELUS International AI-Data Solutions partners...            []
# 4  TELUS International AI-Data Solutions partners...            []
#
#   publication_date applicants
# 0   13 minutes ago        NaN
# 1       4 days ago          6
# 2       6 days ago         12
# 3       6 days ago         11
# 4      8 hours ago          2

# %%
df['link'] = df['html'].apply(lambda x: "https://linkedin.com" + BeautifulSoup(x).find('a').get('href'))
#получаем ссылки на вакансий, для последующей группировке по ним в процессе визуализации

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Фильтрация по релевантным вакансиям

# %% [markdown]
# Прежде чем приступать к предобработке данных отфильтруем все нерелевантные вакансии.

# %%
title_filter = re.compile('''(analyst)|(bi-analyst)|(bi analyst)|(business intelligence analyst)
|(business intelligence-analyst)|(data-analyst)|(data analyst)|(product analyst)|(product-analyst)''', re.X) #фильтр

df['title'] = df['title'].str.lower() #приведение всех названий к нижнему регистру

df_analyst = df[df['title'].str.contains(title_filter)].reset_index(drop=True)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_940/872704697.py:6: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_analyst = df[df['title'].str.contains(title_filter)].reset_index(drop=True)

# %%
df_analyst = df_analyst.explode('skills') #разбивка скиллов на отдельные строки

# %%
df_analyst['title'].unique()
# Out:
# array(['online data analyst', 'online data analyst - belgium',
#        'data analyst', 'alternant/ alternante data analyst m/f',
#        'junior test analyst', 'data analyst h/f',
#        'stage - data analyst (h/f)', 'data analyst (f/h)',
#        'data analyst (tableau)', 'online data analyst | french speaker',
#        'online data analyst | flexible work',
#        'online data analyst | remote opportunity', 'data analyst (it)',
#        'data analyst (m/f/d)', 'data analyst (m/w/d)',
#        'remote | data analyst', 'data analyst sa1/sa2',
#        'data analyst | deals (m&a) | cdi | h/f',
#        'data analyst - adsales & storyworks',
#        'data analyst with focus on solution design (m/f/d)',
#        'remote| data analyst', 'data analyst - (m/f/d)',
#        'alternance - data analyst/dataviz specialist h/f',
#        'data analyst  - boursorama',
#        'technology strategy & advisory junior analyst',
#        'data analyst in forensic technology services team',
#        'junior business analyst', 'analyste exploitation datacenter',
#        'data analyst with python', 'online data analyst in the uk',
#        'data analyst clickshare', 'data analyst - associate',
#        'ingénieur analyste gc/gcms h/f', 'work from home | data analyst',
#        'internet analyst', 'data analyst - performance',
#        'data data analyst with spanish',
#        'junior functional analyst ambito canali',
#        'data analyst (part-time)', 'data analyst customer excellence',
#        'internet analyst (remote)', 'data/analyst data translator (h/f)',
#        'junior business analyst (m/f/d)', 'product data analyst',
#        'data analyst - oxfordshire', 'graduate data analyst',
#        'graduate data analyst 12 month ftc', 'product/data analyst',
#        'data analyst - werkstudent (m/w/d)',
#        'superbe opportunité de data analyst - 100% à martigny',
#        'customer data analyst (m/w/d)',
#        'data analyst düsseldorf/münchen gesucht at jsan consulting gmbh',
#        'data analyst e-commerce (m/w/d)', 'consultant data analyst (f/h)',
#        'remote | internet analyst', 'stage - data analyst marketing f/h',
#        'data internet analyst', 'data analyst rh - f/h',
#        'data development analyst',
#        'data analyst in technology team, financial crime unit',
#        'junior data analyst', 'data analyst (cdm 8 mois)',
#        'asset data analyst',
#        'internet analyst | greater bologna metropolitan area',
#        'data analyst (m/w/d) - automotive',
#        'product data analyst (v.i.e.) h/f', 'data analyst - f/h - idf',
#        'data analyst with spanish (shifts), corporate actions',
#        'material data analyst', 'data analyst (hydro)',
#        'data analyst - part time',
#        'data analyst (product & operations) - sustainability',
#        'data analyst/data-analystin - it forensik (m/w/d)',
#        'operations data analyst (they/she/he)', 'analyst',
#        'analyst big data', '(junior) h2 modelling analyst m/f/t',
#        'data analyst (m/f/d) brand marketing',
#        'internet analyst - remote',
#        'business analyst / consultant it sourcing (m/w/d) in düsseldorf',
#        'stage data analyst h/f', 'analyste risque retail-(h/f)',
#        'data analyst - 9 month fixed term contract',
#        'commercial data analyst', 'junior analyst (j12998)',
#        'incentives analyst', 'data analytics analyst',
#        'data analyst (f/m/d)',
#        'remote opportunity for norwegian speakers | media search analyst',
#        'business intelligence & market insights analyst',
#        'financial analyst', 'environmental data analyst',
#        'data analyst - marketing', 'data analyst tui.com (m/w/d)',
#        'data analyst (tijdelijk - 3 maanden)',
#        'data analyst & coordinator',
#        "data analyst & développement digital de l'audit compagnie f/h",
#        'data analyst télécom (it)', 'performance and data analyst',
#        'solution analyst area mes',
#        'data analyst - analytics and insights - data center of excellence',
#        'junior analyst (j12997)',
#        'data analyst (spotfire and/or mendix, sql and python), veldhoven',
#        'cx data analyst', 'data analyst datalake (f/h)',
#        'apprenti.e data analyst (h/f)',
#        'data analyst (spotfire and/or mendix, sql and python) - veldhoven',
#        'internet analyst | greater turin metropolitan area',
#        'online data analyst - sweden',
#        'part-time work opportunity | online data analyst',
#        'internet analyst (part-time)', 'reporting & data analyst',
#        'junior business analyst (m/w/d)', 'junior analyst (j12995)',
#        'data modelling analyst',
#        'data analyst mit fokus auf up- und crossselling (m/w/d)',
#        'associate data analyst - product analytics',
#        'data analyst - finance', 'internet analyst (remote set-up)',
#        'search engine optimization analyst',
#        'pensions administration data analyst',
#        'data analyst (marketing team)', 'junior analyst (j12996)',
#        'business analyst h/f', 'data analyst & businessobjects developer',
#        'data analyste - h/f - alternance', 'data analyst, digital',
#        'enterprise architect junior analyst [online / phone recruitment]',
#        'data analyst-tecan evo plus and fluent biosero gbg',
#        'junior market data analyst', 'data analyst - demand',
#        'data analyst (insurance) - multiple positions',
#        'data analyst, banking & insurance',
#        'online data analyst - slovenia',
#        'pt compliance hub - data analyst',
#        'commercial data analyst - online travel - london - £40k',
#        'online data analyst - croatia',
#        'location strategy & data analyst', 'cybersecurity data analyst',
#        'data analyst product, cro expert',
#        'web analyst for czech speaker in germany',
#        'media search analyst - german (de)',
#        'data engineering & data warehouse analyst (all genders)',
#        'gis asset data analyst', 'data specialist (steward / analyst)',
#        'analyste data h/f',
#        'data scientist-analyst gers (h/f) - boulogne-billancourt (france)',
#        'customer ledger data analyst',
#        'data analyst (m/f/d) workload planning (business administrator (fachschule) - information processing)',
#        'people systems and data analyst',
#        'product data analyst / analytics engineer — london',
#        'online data analyst - slovakia',
#        'sswhg35824 - data analyst, chair programme, section officer, grade vi',
#        'social media analyst', 'insight analyst',
#        'data analyst | e-commerce & crowdfunding',
#        'quality engineer - product analyst',
#        'data analyst for portuguese speakers',
#        'sample management data analyst',
#        "analyste risques suivi d'activité de marché-(h/f)",
#        'application data analyst hybrid working',
#        'inventory data analyst til europas største kontorartikelleverandør',
#        'data analyst pricing – f/h', 'data analyst - regulatory affairs',
#        'language data analyst - hebrew', 'acoustic data analyst',
#        'systems data analyst', 'junior technical analyst (all genders)',
#        'functional analyst', 'hr group reward & hr data analyst',
#        'media search analyst | french speaker', 'interim hr data analyst',
#        'language researcher / data analyst - french',
#        'online data analyst - hungary', 'p2p operations credit analyst',
#        'ing. elettronico/data analyst',
#        'customer data platform (cdp) specialist / customer data consultant / martech expert / data analyst (h/f)',
#        'data analyst / consultant qlikview/qliksense (m/w/d)',
#        'quality assurance analyst',
#        'scientific programmer and data analyst', 'genomics data analyst',
#        'data research analyst', 'junior business intelligence analyst',
#        'praktikant / werkstudent data analyst (m/w/d) financial services industry',
#        'bi data analyst intern (f/m/x)',
#        'internet analyst | florence, italy metropolitan area',
#        'graduate marketing technology analyst', 'junior energy analyst',
#        'language data analyst',
#        'data junior analyst [online / phone recruitment]',
#        'traffic analyst',
#        'assistenz (w/m/d) des ceo west - schwerpunkt data analyst / controlling',
#        'purchasing analyst (m/w/d) 100%', 'pressure analyst',
#        'business analyst', 'business analyst h/f - bordeaux',
#        'junior sap analyst'], dtype=object)

# %% [markdown]
# Уберём из полученного датафрейма одну из специальностей явно не связанную с дата-аналитикой - "pressure analyst".

# %%
df_analyst = df_analyst.query('title != "pressure analyst"')

# %%
def information(df): #функция для получения общих сведений о датафрейме
    print('\033[1m' + 'Общая информация:' + '\033[0m')
    df.info()
    print()
    print('\033[1m' + 'Первые 2 строки:' + '\033[0m')
    display(df.head(2))
    print('\033[1m' + 'Количество дубликатов:' + '\033[0m', df.duplicated().sum())
    print()
    print('\033[1m' + 'Количество пропусков:' + '\033[0m')
    display(df.isna().sum())
    print('\033[1m' + 'Доля пропусков:' + '\033[0m')
    print(df.isna().sum() / len(df))

# %%
information(df_analyst)
# Out:
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 974 entries, 0 to 353
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              974 non-null    int64
#  1   html                    974 non-null    object
#  2   title                   974 non-null    object
#  3   geo                     974 non-null    object
#  4   city                    935 non-null    object
#  5   country                 914 non-null    object
#  6   workplace_type          772 non-null    object
#  7   company_name            974 non-null    object
#  8   employees               971 non-null    object
#  9   company_specialization  904 non-null    object
#  10  description             974 non-null    object
#  11  skills                  873 non-null    object
#  12  publication_date        974 non-null    object
#  13  applicants              875 non-null    object
#  14  link                    974 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 121.8+ KB
#
# Первые 2 строки:
#    Unnamed: 0                                               html  \
# 0           2  \n  <div>\n    <div class="\n        jobs-deta...
# 1           3  \n  <div>\n    <div class="\n        jobs-deta...
#
#                            title                                     geo  \
# 0            online data analyst   Skara, Vastra Gotaland County, Sweden
# 1  online data analyst - belgium  West Flanders, Flemish Region, Belgium
#
#             city  country workplace_type  \
# 0          Skara   Sweden         Remote
# 1  West Flanders  Belgium         Remote
#
#                             company_name           employees  \
# 0  TELUS International AI Data Solutions  10,001+ employees
# 1                    TELUS International  10,001+ employees
#
#            company_specialization  \
# 0   IT Services and IT Consulting
# 1   IT Services and IT Consulting
#
#                                          description skills publication_date  \
# 0  TELUS International AI-Data Solutions partners...    NaN       6 days ago
# 1  TELUS International AI-Data Solutions partners...    NaN       6 days ago
#
#   applicants                                               link
# 0         12  https://linkedin.com/jobs/view/3248499929/?alt...
# 1         11  https://linkedin.com/jobs/view/3248879065/?alt...
# Количество дубликатов: 0
#
# Количество пропусков:
# Unnamed: 0                  0
# html                        0
# title                       0
# geo                         0
# city                       39
# country                    60
# workplace_type            202
# company_name                0
# employees                   3
# company_specialization     70
# description                 0
# skills                    101
# publication_date            0
# applicants                 99
# link                        0
# dtype: int64
# Доля пропусков:
# Unnamed: 0               0.00
# html                     0.00
# title                    0.00
# geo                      0.00
# city                     0.04
# country                  0.06
# workplace_type           0.21
# company_name             0.00
# employees                0.00
# company_specialization   0.07
# description              0.00
# skills                   0.10
# publication_date         0.00
# applicants               0.10
# link                     0.00
# dtype: float64

# %% [markdown]
# В получившемся датафрейме отсутствуют дубликаты, но есть пропуски в нескольких столбцах. Также есть лишние столбцы, а данные о дате размещения вакансии необходимо привести к соответствующему виду, чтобы они были представлены реальной датой, а не временным промежутком с момента публикации до момента парсинга.

# %%
df_analyst = df_analyst.drop(['Unnamed: 0', 'html', 'geo', 'description'], axis=1) #удаление ненужных столбцов

# %% [markdown]
# ### Получение даты публикации вакансии

# %%
df_analyst['publication_date'].unique()
# Out:
# array(['6 days ago', '8 hours ago', '5 days ago', '1 day ago',
#        '2 days ago', '7 hours ago', '16 hours ago', '3 hours ago',
#        '23 hours ago', '2 hours ago', '15 hours ago', '19 hours ago',
#        '21 hours ago', '9 hours ago', '14 hours ago', '4 hours ago',
#        '3 days ago', '4 days ago', '6 hours ago', '18 hours ago',
#        '11 hours ago', '10 minutes ago', '5 hours ago', '1 week ago',
#        '10 hours ago', '22 hours ago'], dtype=object)

# %%
df_analyst['time'] = df_analyst['publication_date'].str.split(' ').str.get(0)
df_analyst['time_units'] = df_analyst['publication_date'].str.split(' ').str.get(1)
df_analyst['time'] = df_analyst['time'].astype('int')
#разбиваем информацию о временном промежутке на два столбца, и приводим количество единиц времени к целочисленному формату

# %%
def time_to_unix(row): #функция для перевода единиц времени в формат unix
    if row['time_units'] == 'day' or row['time_units'] == 'days':
        return row['time'] * 86400
    elif row['time_units'] == 'hours':
        return row['time'] * 3600
    elif row['time_units'] == 'minutes':
        return row['time'] * 60
    else:
        return row['time'] * 604800

# %%
df_analyst['publication_date'] = df_analyst.apply(time_to_unix, axis=1)

df_analyst['publication_date'] = 1662570000 - df_analyst['publication_date'] #получение даты публикации в формате unix

# %%
df_analyst['publication_date'] = df_analyst['publication_date'].apply(
    lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d')) #перевод даты публикации из формата unix в datetime

# %%
df_analyst = df_analyst.drop(['time', 'time_units'], axis=1) #удаление побочных столбцов

# %% [markdown]
# ### Обработка пропусков и аномальных значений

# %%
df_analyst[df_analyst['city'].isna()]
# Out:
#                                         title city         country  \
# 10                     data analyst (tableau)  NaN       Gibraltar
# 10                     data analyst (tableau)  NaN       Gibraltar
# 10                     data analyst (tableau)  NaN       Gibraltar
# 10                     data analyst (tableau)  NaN       Gibraltar
# 10                     data analyst (tableau)  NaN       Gibraltar
# 13                               data analyst  NaN          Poland
# 32              online data analyst - belgium  NaN         Belgium
# 66                           internet analyst  NaN          Poland
# 80                               data analyst  NaN          Poland
# 96                        online data analyst  NaN         Finland
# 97                               data analyst  NaN         Germany
# 107                 remote | internet analyst  NaN        Slovakia
# 111             work from home | data analyst  NaN          Poland
# 128                              data analyst  NaN         Germany
# 147                  data analyst - part time  NaN          Poland
# 192      data analyst (tijdelijk - 3 maanden)  NaN     Netherlands
# 206                 internet analyst - remote  NaN        Slovakia
# 213                   junior analyst (j12997)  NaN          France
# 213                   junior analyst (j12997)  NaN          France
# 216                          internet analyst  NaN        Slovakia
# 223              online data analyst - sweden  NaN          Sweden
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 255                              data analyst  NaN  United Kingdom
# 257              online data analyst - sweden  NaN          Sweden
# 264            online data analyst - slovenia  NaN        Slovenia
# 267             online data analyst - croatia  NaN         Croatia
# 271                cybersecurity data analyst  NaN     Switzerland
# 271                cybersecurity data analyst  NaN     Switzerland
# 274  web analyst for czech speaker in germany  NaN         Germany
# 300      data analyst for portuguese speakers  NaN        Portugal
# 343                           traffic analyst  NaN         Croatia
# 343                           traffic analyst  NaN         Croatia
#
#     workplace_type                           company_name  \
# 10             NaN                          Guardian Jobs
# 10             NaN                          Guardian Jobs
# 10             NaN                          Guardian Jobs
# 10             NaN                          Guardian Jobs
# 10             NaN                          Guardian Jobs
# 13          Remote  TELUS International AI Data Solutions
# 32          Remote                    TELUS International
# 66          Remote  TELUS International AI Data Solutions
# 80          Remote  TELUS International AI Data Solutions
# 96          Remote                    TELUS International
# 97          Remote  TELUS International AI Data Solutions
# 107         Remote  TELUS International AI Data Solutions
# 111         Remote  TELUS International AI Data Solutions
# 128         Remote  TELUS International AI Data Solutions
# 147         Remote  TELUS International AI Data Solutions
# 192         Remote                 Independent Recruiters
# 206         Remote  TELUS International AI Data Solutions
# 213         Remote                                 Pareto
# 213         Remote                                 Pareto
# 216         Remote  TELUS International AI Data Solutions
# 223         Remote                    TELUS International
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 255         Remote                               Endeavor
# 257         Remote                    TELUS International
# 264         Remote                    TELUS International
# 267         Remote                    TELUS International
# 271         Remote                        Nozomi Networks
# 271         Remote                        Nozomi Networks
# 274         Remote                                  Appen
# 300         Remote                                  Appen
# 343         Remote                          VOX SOLUTIONS
# 343         Remote                          VOX SOLUTIONS
#
#                    employees          company_specialization     skills  \
# 10         51-200 employees          Staffing and Recruiting        api
# 10         51-200 employees          Staffing and Recruiting      excel
# 10         51-200 employees          Staffing and Recruiting     python
# 10         51-200 employees          Staffing and Recruiting        sql
# 10         51-200 employees          Staffing and Recruiting    tableau
# 13        10,001+ employees    IT Services and IT Consulting        NaN
# 32        10,001+ employees    IT Services and IT Consulting        NaN
# 66        10,001+ employees    IT Services and IT Consulting        NaN
# 80        10,001+ employees    IT Services and IT Consulting        NaN
# 96        10,001+ employees    IT Services and IT Consulting        NaN
# 97        10,001+ employees    IT Services and IT Consulting        NaN
# 107       10,001+ employees    IT Services and IT Consulting        NaN
# 111       10,001+ employees    IT Services and IT Consulting        NaN
# 128       10,001+ employees    IT Services and IT Consulting        NaN
# 147       10,001+ employees    IT Services and IT Consulting        NaN
# 192         11-50 employees          Staffing and Recruiting      excel
# 206       10,001+ employees    IT Services and IT Consulting        NaN
# 213       201-500 employees          Staffing and Recruiting      excel
# 213       201-500 employees          Staffing and Recruiting       java
# 216       10,001+ employees    IT Services and IT Consulting        NaN
# 223       10,001+ employees    IT Services and IT Consulting        NaN
# 255  5,001-10,000 employees          Entertainment Providers        aws
# 255  5,001-10,000 employees          Entertainment Providers      azure
# 255  5,001-10,000 employees          Entertainment Providers      excel
# 255  5,001-10,000 employees          Entertainment Providers  snowflake
# 255  5,001-10,000 employees          Entertainment Providers     python
# 255  5,001-10,000 employees          Entertainment Providers         r
# 255  5,001-10,000 employees          Entertainment Providers        sql
# 255  5,001-10,000 employees          Entertainment Providers    tableau
# 255  5,001-10,000 employees          Entertainment Providers   power bi
# 257       10,001+ employees    IT Services and IT Consulting        NaN
# 264       10,001+ employees    IT Services and IT Consulting        NaN
# 267       10,001+ employees    IT Services and IT Consulting        NaN
# 271       201-500 employees    Computer and Network Security        api
# 271       201-500 employees    Computer and Network Security     python
# 274     501-1,000 employees    IT Services and IT Consulting        NaN
# 300     501-1,000 employees    IT Services and IT Consulting        NaN
# 343         51-200 employees                             NaN      excel
# 343         51-200 employees                             NaN     python
#
#     publication_date applicants  \
# 10        2022-09-06         30
# 10        2022-09-06         30
# 10        2022-09-06         30
# 10        2022-09-06         30
# 10        2022-09-06         30
# 13        2022-09-07          9
# 32        2022-09-01         11
# 66        2022-09-07          7
# 80        2022-09-02          9
# 96        2022-09-01         15
# 97        2022-09-02         22
# 107       2022-09-05          5
# 111       2022-09-05         42
# 128       2022-09-01         28
# 147       2022-09-01         13
# 192       2022-09-05         19
# 206       2022-09-02          2
# 213       2022-09-02         60
# 213       2022-09-02         60
# 216       2022-09-02          3
# 223       2022-09-06         85
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 255       2022-09-05        NaN
# 257       2022-09-06         45
# 264       2022-09-01         26
# 267       2022-09-01         63
# 271       2022-09-02         27
# 271       2022-09-02         27
# 274       2022-09-07        NaN
# 300       2022-09-05        137
# 343       2022-09-06         10
# 343       2022-09-06         10
#
#                                                   link
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 13   https://linkedin.com/jobs/view/3257231590/?alt...
# 32   https://linkedin.com/jobs/view/3248871894/?alt...
# 66   https://linkedin.com/jobs/view/3249290419/?alt...
# 80   https://linkedin.com/jobs/view/3249557969/?alt...
# 96   https://linkedin.com/jobs/view/3248881314/?alt...
# 97   https://linkedin.com/jobs/view/3249559738/?alt...
# 107  https://linkedin.com/jobs/view/3252951037/?alt...
# 111  https://linkedin.com/jobs/view/3255010240/?alt...
# 128  https://linkedin.com/jobs/view/3247043224/?alt...
# 147  https://linkedin.com/jobs/view/3247041349/?alt...
# 192  https://linkedin.com/jobs/view/3255265728/?alt...
# 206  https://linkedin.com/jobs/view/3249558588/?alt...
# 213  https://linkedin.com/jobs/view/3248177345/?alt...
# 213  https://linkedin.com/jobs/view/3248177345/?alt...
# 216  https://linkedin.com/jobs/view/3249561608/?alt...
# 223  https://linkedin.com/jobs/view/3155718616/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 255  https://linkedin.com/jobs/view/3229956189/?alt...
# 257  https://linkedin.com/jobs/view/3155727277/?alt...
# 264  https://linkedin.com/jobs/view/3247484980/?alt...
# 267  https://linkedin.com/jobs/view/3247486261/?alt...
# 271  https://linkedin.com/jobs/view/3243819090/?alt...
# 271  https://linkedin.com/jobs/view/3243819090/?alt...
# 274  https://linkedin.com/jobs/view/3249278702/?alt...
# 300  https://linkedin.com/jobs/view/3247186771/?alt...
# 343  https://linkedin.com/jobs/view/3253788059/?alt...
# 343  https://linkedin.com/jobs/view/3253788059/?alt...

# %% [markdown]
# Все вакансии для которых не указан город, за исключением одной, подразумевают удаленный формат работы, поэтому указывать для них город дислокации нет смысла, ещё одна вакансия находится в Гибраалтаре который сам по себе фактически является городом-государством, т.е. замена пропусков в данном случае не требуется.

# %%
df_analyst[df_analyst['country'].isna()]['city'].unique()
# Out:
# array(['Przemyśl', 'Grudziadz', 'Norrköping', 'Radom', 'Zamosc',
#        'Edinburgh', 'Lodz', 'Mons', 'Milan', 'Bologna', 'Ghent', 'Bruges',
#        'Gijón', 'Kortrijk', 'Rome', 'Zurich', 'Namur', 'Barcelona',
#        'Turin', 'Brussels', 'Paris', 'Antwerp', 'Warsaw', 'Genoa',
#        'Liege', 'Louvain', 'Athens'], dtype=object)

# %%
def country(row): #функция для замены пропусков в стране по городу
    if row['city'] in ['Przemyśl', 'Grudziadz', 'Radom', 'Zamosc', 'Lodz', 'Warsaw']:
        return 'Poland'
    elif row['city'] in ['Norrköping']:
        return 'Sweden'
    elif row['city'] in ['Edinburgh']:
        return 'Scotland'
    elif row['city'] in ['Mons', 'Ghent', 'Bruges', 'Kortrijk', 'Namur', 'Brussels', 'Antwerp', 'Liege', 'Louvain']:
        return 'Belgium'
    elif row['city'] in ['Milan', 'Bologna', 'Rome', 'Turin', 'Genoa']:
        return 'Italy'
    elif row['city'] in ['Gijón', 'Barcelona']:
        return 'Spain'
    elif row['city'] in ['Zurich']:
        return 'Switzerland'
    elif row['city'] in ['Paris']:
        return 'France'
    elif row['city'] in ['Athens']:
        return 'Greece'
    else:
        return row['country']

# %%
df_analyst['country'] = df_analyst.apply(country, axis=1)

# %%
df_analyst['country'].isna().sum()
# Out:
# 0

# %%
df_analyst[df_analyst['workplace_type'].isna()]
# Out:
#                                title        city         country  \
# 10            data analyst (tableau)         NaN       Gibraltar
# 10            data analyst (tableau)         NaN       Gibraltar
# 10            data analyst (tableau)         NaN       Gibraltar
# 10            data analyst (tableau)         NaN       Gibraltar
# 10            data analyst (tableau)         NaN       Gibraltar
# ..                               ...         ...             ...
# 311             systems data analyst      London  United Kingdom
# 321    online data analyst - hungary    Budapest         Hungary
# 348          junior business analyst  Hartlepool  United Kingdom
# 348          junior business analyst  Hartlepool  United Kingdom
# 351  business analyst h/f - bordeaux    Bordeaux          France
#
#     workplace_type          company_name           employees  \
# 10             NaN         Guardian Jobs   51-200 employees
# 10             NaN         Guardian Jobs   51-200 employees
# 10             NaN         Guardian Jobs   51-200 employees
# 10             NaN         Guardian Jobs   51-200 employees
# 10             NaN         Guardian Jobs   51-200 employees
# ..             ...                   ...                 ...
# 311            NaN          dns umbrella     1-10 employees
# 321            NaN   TELUS International  10,001+ employees
# 348            NaN  Paul Gough Media LLC    11-50 employees
# 348            NaN  Paul Gough Media LLC    11-50 employees
# 351            NaN               Avanade  10,001+ employees
#
#              company_specialization    skills publication_date applicants  \
# 10          Staffing and Recruiting       api       2022-09-06         30
# 10          Staffing and Recruiting     excel       2022-09-06         30
# 10          Staffing and Recruiting    python       2022-09-06         30
# 10          Staffing and Recruiting       sql       2022-09-06         30
# 10          Staffing and Recruiting   tableau       2022-09-06         30
# ..                              ...       ...              ...        ...
# 311              Financial Services  power bi       2022-09-01        NaN
# 321   IT Services and IT Consulting       NaN       2022-09-07         36
# 348            Advertising Services       api       2022-09-02         38
# 348            Advertising Services      ssis       2022-09-02         38
# 351   IT Services and IT Consulting       api       2022-09-02          5
#
#                                                   link
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# 10   https://linkedin.com/jobs/view/3248368719/?alt...
# ..                                                 ...
# 311  https://linkedin.com/jobs/view/3256666230/?alt...
# 321  https://linkedin.com/jobs/view/3156985237/?alt...
# 348  https://linkedin.com/jobs/view/3247376375/?alt...
# 348  https://linkedin.com/jobs/view/3247376375/?alt...
# 351  https://linkedin.com/jobs/view/3243892066/?alt...
#
# [202 rows x 11 columns]

# %% [markdown]
# Подходящей замены для пропусков типа рабочего места нет, поэтому заменим эти пропуски заглушками 'unknown'.

# %%
df_analyst['workplace_type'] = df_analyst['workplace_type'].fillna('unknown')

# %%
df_analyst['workplace_type'].isna().sum()
# Out:
# 0

# %%
df_analyst[df_analyst['company_specialization'].isna()]
# Out:
#                                                  title        city  \
# 148  data analyst (product & operations) - sustaina...       Paris
# 148  data analyst (product & operations) - sustaina...       Paris
# 148  data analyst (product & operations) - sustaina...       Paris
# 148  data analyst (product & operations) - sustaina...       Paris
# 148  data analyst (product & operations) - sustaina...       Paris
# ..                                                 ...         ...
# 303            application data analyst hybrid working  Birmingham
# 319                            interim hr data analyst   Worcester
# 319                            interim hr data analyst   Worcester
# 343                                    traffic analyst         NaN
# 343                                    traffic analyst         NaN
#
#             country workplace_type                  company_name  \
# 148          France         Hybrid                       Greenly
# 148          France         Hybrid                       Greenly
# 148          France         Hybrid                       Greenly
# 148          France         Hybrid                       Greenly
# 148          France         Hybrid                       Greenly
# ..              ...            ...                           ...
# 303  United Kingdom        unknown
# 319  United Kingdom        On-site  Ashley Kate HR &amp; Finance
# 319  United Kingdom        On-site  Ashley Kate HR &amp; Finance
# 343         Croatia         Remote                 VOX SOLUTIONS
# 343         Croatia         Remote                 VOX SOLUTIONS
#
#                                              employees company_specialization  \
# 148                                   51-200 employees                    NaN
# 148                                   51-200 employees                    NaN
# 148                                   51-200 employees                    NaN
# 148                                   51-200 employees                    NaN
# 148                                   51-200 employees                    NaN
# ..                                                 ...                    ...
# 303                      IT Services and IT Consulting                    NaN
# 319  See recent hiring trends for Ashley Kate HR &a...                    NaN
# 319  See recent hiring trends for Ashley Kate HR &a...                    NaN
# 343                                   51-200 employees                    NaN
# 343                                   51-200 employees                    NaN
#
#      skills publication_date applicants  \
# 148     api       2022-09-06         40
# 148   excel       2022-09-06         40
# 148  python       2022-09-06         40
# 148   scala       2022-09-06         40
# 148     sql       2022-09-06         40
# ..      ...              ...        ...
# 303     sql       2022-09-02        NaN
# 319   excel       2022-09-01          1
# 319    ssis       2022-09-01          1
# 343   excel       2022-09-06         10
# 343  python       2022-09-06         10
#
#                                                   link
# 148  https://linkedin.com/jobs/view/3249141676/?alt...
# 148  https://linkedin.com/jobs/view/3249141676/?alt...
# 148  https://linkedin.com/jobs/view/3249141676/?alt...
# 148  https://linkedin.com/jobs/view/3249141676/?alt...
# 148  https://linkedin.com/jobs/view/3249141676/?alt...
# ..                                                 ...
# 303  https://linkedin.com/jobs/view/3249913331/?alt...
# 319  https://linkedin.com/jobs/view/3247334292/?alt...
# 319  https://linkedin.com/jobs/view/3247334292/?alt...
# 343  https://linkedin.com/jobs/view/3253788059/?alt...
# 343  https://linkedin.com/jobs/view/3253788059/?alt...
#
# [70 rows x 11 columns]

# %%
df_analyst[df_analyst['company_specialization'].isna()]['company_name'].unique()
# Out:
# array(['Greenly', 'Landeskriminalamt Nordrhein-Westfalen',
#        'M&L Aktiengesellschaft', 'Expectoo Nigeria', 'Software * IT',
#        'BeTechnology Group', 'HR Proactivity',
#        'Randstad Tech Engineering', 'Web Leaders - Winning People',
#        'Quantum Advisory', 'Mec-Diesel S.p.A.', 'Viceversa',
#        'Birnbach Communications', 'www.TeamQuest.pl', 'Tefors', '',
#        'Ashley Kate HR &amp; Finance', 'VOX SOLUTIONS'], dtype=object)

# %%
def company_specialization(row): #функция для замены пропусков сфере деятельности по названию компании
    if row['company_name'] in ['Greenly']:
        return 'Environmental Services'
    elif row['company_name'] in ['Landeskriminalamt Nordrhein-Westfalen']:
        return 'Government Administration'
    elif row['company_name'] in ['M&L Aktiengesellschaft']:
        return 'Business Consulting and Services'
    elif row['company_name'] in ['Expectoo Nigeria', '']:
        return 'IT Services and IT Consulting'
    elif row['company_name'] in ['HR Proactivity', 'www.TeamQuest.pl']:
        return 'Human Resources Services'
    elif row['company_name'] in ['Software * IT', 'BeTechnology Group', 'Randstad Tech Engineering']:
        return 'agency vacancy'
    elif row['company_name'] in ['Web Leaders - Winning People']:
        return 'Advertising Services'
    elif row['company_name'] in ['Quantum Advisory']:
        return 'Accounting'
    elif row['company_name'] in ['Mec-Diesel S.p.A.']:
        return 'Wholesale Motor Vehicles and Parts'
    elif row['company_name'] in ['Viceversa']:
        return 'Financial Services'
    elif row['company_name'] in ['Birnbach Communications']:
        return 'Public Relations and Communications Services'
    elif row['company_name'] in ['Tefors']:
        return 'Retail Apparel and Fashion'
    elif row['company_name'] in ['Ashley Kate HR &amp; Finance']:
        return 'Staffing and Recruiting'
    elif row['company_name'] in ['VOX SOLUTIONS']:
        return 'Telecommunications'
    else:
        return row['company_specialization']

# %%
df_analyst['company_specialization'] = df_analyst.apply(company_specialization, axis=1)

# %%
df_analyst['company_specialization'].isna().sum()
# Out:
# 0

# %%
df_analyst[df_analyst['employees'].isna()]
# Out:
#                             title       city         country workplace_type  \
# 282  customer ledger data analyst  Stockport  United Kingdom        On-site
# 282  customer ledger data analyst  Stockport  United Kingdom        On-site
# 282  customer ledger data analyst  Stockport  United Kingdom        On-site
#
#                 company_name employees  \
# 282  Birnbach Communications       NaN
# 282  Birnbach Communications       NaN
# 282  Birnbach Communications       NaN
#
#                            company_specialization skills publication_date  \
# 282  Public Relations and Communications Services  excel       2022-09-06
# 282  Public Relations and Communications Services   ssis       2022-09-06
# 282  Public Relations and Communications Services    vba       2022-09-06
#
#     applicants                                               link
# 282        NaN  https://linkedin.com/jobs/view/3254329032/?alt...
# 282        NaN  https://linkedin.com/jobs/view/3254329032/?alt...
# 282        NaN  https://linkedin.com/jobs/view/3254329032/?alt...

# %%
df_analyst['employees'].value_counts()
# Out:
# 10,001+ employees                                                                                   274
# 1,001-5,000 employees                                                                               138
# 201-500 employees                                                                                   114
# 501-1,000 employees                                                                                 106
# 51-200 employees                                                                                     94
# 5,001-10,000 employees                                                                               90
# 1-10 employees                                                                                       52
# 11-50 employees                                                                                      36
# 1-10 employees                                                                                       18
# 51-200 employees                                                                                     15
# See recent hiring trends for Software * IT. Unlock more Premium insights for free                     8
# See recent hiring trends for www.TeamQuest.pl. Unlock more Premium insights for free                  6
# See how you compare to 3 applicants. Unlock more Premium insights for free                            5
# See how you compare to 6 applicants. Unlock more Premium insights for free                            3
# 201-500 employees                                                                                     3
# See how you compare to 4 applicants. Unlock more Premium insights for free                            3
# IT Services and IT Consulting                                                                         2
# See recent hiring trends for Ashley Kate HR &amp; Finance. Unlock more Premium insights for free      2
# Government Administration                                                                             1
# See how you compare to 14 applicants. Unlock more Premium insights for free                           1
# Name: employees, dtype: int64

# %% [markdown]
# В столбце с количеством сотрудников в компании всего 3 пропуска, но также присутствуют аномальные значения.

# %%
df_analyst['employees'] = df_analyst['employees'].fillna('unknown') #заглушка на пропуск

employees = re.compile('(employees)') #фильтр

df_analyst[~(df_analyst['employees'].str.contains(employees))]['company_name'].unique() #получение названий компаний
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_940/1691843247.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_analyst[~(df_analyst['employees'].str.contains(employees))]['company_name'].unique() #получение названий компаний
# array(['Landeskriminalamt Nordrhein-Westfalen', 'M&L Aktiengesellschaft',
#        'Software * IT', 'BeTechnology Group', 'Randstad Tech Engineering',
#        'Birnbach Communications', 'www.TeamQuest.pl', '',
#        'Ashley Kate HR &amp; Finance'], dtype=object)

# %%
def employees(row): #функция для замены значений в столбце с количеством сотрудников:
    if row['company_name'] in ['Landeskriminalamt Nordrhein-Westfalen', 'Software * IT', 
                               'BeTechnology Group', 'Randstad Tech Engineering', '']:
        return 'unknown'
    elif row['company_name'] in ['M&L Aktiengesellschaft', 'www.TeamQuest.pl', 'Ashley Kate HR &amp; Finance']:
        return '11-50 employees'
    elif row['company_name'] in ['Birnbach Communications']:
        return '1-10 employees'
    else:
        return row['employees']

# %%
df_analyst['employees'] = df_analyst.apply(employees, axis=1)

# %%
df_analyst['employees'].value_counts()
# Out:
# 10,001+ employees          274
# 1,001-5,000 employees      128
# 201-500 employees          114
# 501-1,000 employees        106
# 51-200 employees            94
# 5,001-10,000 employees      90
# 1-10 employees              45
# 11-50 employees             36
# unknown                     36
# 1-10 employees              21
# 51-200 employees            15
# 11-50 employees             12
# 201-500 employees            3
# Name: employees, dtype: int64

# %% [markdown]
# Аномальные значения исчезли, но некоторые строки с одинаковыми значениями опрделяются, как разные значения (возможно из-за пробелов). Оставим только числовой диапазон в столбце а слово 'employees' уберем.

# %%
df_analyst['employees'] = df_analyst['employees'].str.split(' ').str.get(0)

# %%
df_analyst['employees'].value_counts()
# Out:
# 10,001+         274
# 1,001-5,000     128
# 201-500         117
# 51-200          109
# 501-1,000       106
# 5,001-10,000     90
# 1-10             66
# 11-50            48
# unknown          36
# Name: employees, dtype: int64

# %%
df_analyst[df_analyst['applicants'].isna()]
# Out:
#                                                  title        city  \
# 6                                         data analyst    Przemyśl
# 24                                        data analyst     Castres
# 24                                        data analyst     Castres
# 24                                        data analyst     Castres
# 57                            data analyst with python       Sofia
# ..                                                 ...         ...
# 311                               systems data analyst      London
# 311                               systems data analyst      London
# 324                      ing. elettronico/data analyst        Rome
# 324                      ing. elettronico/data analyst        Rome
# 344  assistenz (w/m/d) des ceo west - schwerpunkt d...  Düsseldorf
#
#             country workplace_type                           company_name  \
# 6            Poland         Remote  TELUS International AI Data Solutions
# 24           France        On-site                     Pierre Fabre Group
# 24           France        On-site                     Pierre Fabre Group
# 24           France        On-site                     Pierre Fabre Group
# 57         Bulgaria        unknown                                 Fourth
# ..              ...            ...                                    ...
# 311  United Kingdom        unknown                           dns umbrella
# 311  United Kingdom        unknown                           dns umbrella
# 324           Italy        On-site                                 Herzum
# 324           Italy        On-site                                 Herzum
# 344         Germany        On-site                       Rhenus Logistics
#
#      employees                             company_specialization  \
# 6      10,001+                      IT Services and IT Consulting
# 24     10,001+                       Pharmaceutical Manufacturing
# 24     10,001+                       Pharmaceutical Manufacturing
# 24     10,001+                       Pharmaceutical Manufacturing
# 57   501-1,000                      IT Services and IT Consulting
# ..         ...                                                ...
# 311       1-10                                 Financial Services
# 311       1-10                                 Financial Services
# 324     51-200                      IT Services and IT Consulting
# 324     51-200                      IT Services and IT Consulting
# 344    10,001+   Transportation, Logistics, Supply Chain and S...
#
#           skills publication_date applicants  \
# 6            NaN       2022-09-07        NaN
# 24         excel       2022-09-02        NaN
# 24   power point       2022-09-02        NaN
# 24       tableau       2022-09-02        NaN
# 57           api       2022-09-07        NaN
# ..           ...              ...        ...
# 311  data studio       2022-09-01        NaN
# 311     power bi       2022-09-01        NaN
# 324       python       2022-09-06        NaN
# 324          c++       2022-09-06        NaN
# 344         ssis       2022-09-07        NaN
#
#                                                   link
# 6    https://linkedin.com/jobs/view/3257247449/?alt...
# 24   https://linkedin.com/jobs/view/2811860634/?alt...
# 24   https://linkedin.com/jobs/view/2811860634/?alt...
# 24   https://linkedin.com/jobs/view/2811860634/?alt...
# 57   https://linkedin.com/jobs/view/3249889835/?alt...
# ..                                                 ...
# 311  https://linkedin.com/jobs/view/3256666230/?alt...
# 311  https://linkedin.com/jobs/view/3256666230/?alt...
# 324  https://linkedin.com/jobs/view/3254064694/?alt...
# 324  https://linkedin.com/jobs/view/3254064694/?alt...
# 344  https://linkedin.com/jobs/view/3257308691/?alt...
#
# [99 rows x 11 columns]

# %% [markdown]
# Для вакансий которые были опубликованы непосредственно в день парсинга отсутствия значений в данном столбце можно было бы объснить тем, что претенденты не успели появиться, но пропуски есть и в вакансиях опубликованных позднее (возможно на вакансию действительно никто не откликнулся или данная информация просто скрыта). В данном столбце оставим Nan без изменений.

# %%
df_analyst.duplicated().sum() #проверка на дубликаты после проведенных преобразований
# Out:
# 0

# %%
df_analyst = df_analyst.drop_duplicates().reset_index(drop=True) #удаление дубликата

# %%
df_analyst.to_csv('D:\df_analyst.csv', index=False) #выгрузка датафрейма в csv-файл

# %% [markdown]
# ## Ссылка на дашборд

# %% [markdown]
# [https://public.tableau.com/views/Linkedin_project/Dashboard1?:language=en-US&:display_count=n&:origin=viz_share_link]
